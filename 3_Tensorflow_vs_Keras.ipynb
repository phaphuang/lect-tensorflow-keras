# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Activation, Dense

training_data = np.array([[0,0],[0,1],[1,0],[1,1]], "float32")
target_data = np.array([[0],[1],[1],[0]], "float32")

model = Sequential()
model.add(Dense(32, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['binary_accuracy'])

model.fit(training_data, target_data, epochs=100)

print(model.predict(training_data))
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2476 - binary_accuracy: 0.7500
# Epoch 2/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2471 - binary_accuracy: 0.5000
# Epoch 3/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2466 - binary_accuracy: 0.5000
# Epoch 4/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2461 - binary_accuracy: 0.5000
# Epoch 5/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2456 - binary_accuracy: 0.7500
# Epoch 6/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2450 - binary_accuracy: 0.7500
# Epoch 7/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2445 - binary_accuracy: 0.7500
# Epoch 8/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2440 - binary_accuracy: 0.7500
# Epoch 9/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2435 - binary_accuracy: 0.7500
# Epoch 10/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2430 - binary_accuracy: 0.7500
# Epoch 11/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2425 - binary_accuracy: 0.7500
# Epoch 12/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2420 - binary_accuracy: 0.7500
# Epoch 13/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2415 - binary_accuracy: 0.7500
# Epoch 14/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2410 - binary_accuracy: 0.7500
# Epoch 15/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2406 - binary_accuracy: 0.7500
# Epoch 16/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2401 - binary_accuracy: 0.7500
# Epoch 17/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2396 - binary_accuracy: 0.7500
# Epoch 18/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2391 - binary_accuracy: 0.7500
# Epoch 19/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2386 - binary_accuracy: 0.7500
# Epoch 20/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2381 - binary_accuracy: 0.7500
# Epoch 21/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2377 - binary_accuracy: 0.7500
# Epoch 22/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2372 - binary_accuracy: 0.7500
# Epoch 23/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2368 - binary_accuracy: 0.7500
# Epoch 24/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2363 - binary_accuracy: 0.7500
# Epoch 25/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2359 - binary_accuracy: 0.7500
# Epoch 26/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2354 - binary_accuracy: 0.7500
# Epoch 27/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2350 - binary_accuracy: 0.7500
# Epoch 28/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2345 - binary_accuracy: 0.7500
# Epoch 29/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2341 - binary_accuracy: 0.7500
# Epoch 30/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2337 - binary_accuracy: 0.7500
# Epoch 31/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2332 - binary_accuracy: 0.7500
# Epoch 32/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2328 - binary_accuracy: 0.7500
# Epoch 33/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2323 - binary_accuracy: 0.7500
# Epoch 34/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2319 - binary_accuracy: 0.7500
# Epoch 35/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2314 - binary_accuracy: 0.7500
# Epoch 36/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2310 - binary_accuracy: 0.7500
# Epoch 37/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2305 - binary_accuracy: 0.7500
# Epoch 38/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2301 - binary_accuracy: 0.7500
# Epoch 39/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2296 - binary_accuracy: 0.7500
# Epoch 40/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2292 - binary_accuracy: 0.7500
# Epoch 41/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2287 - binary_accuracy: 0.7500
# Epoch 42/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2283 - binary_accuracy: 0.7500
# Epoch 43/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2278 - binary_accuracy: 0.7500
# Epoch 44/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2274 - binary_accuracy: 0.7500
# Epoch 45/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2269 - binary_accuracy: 0.7500
# Epoch 46/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2265 - binary_accuracy: 0.7500
# Epoch 47/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2261 - binary_accuracy: 0.7500
# Epoch 48/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2256 - binary_accuracy: 0.7500
# Epoch 49/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2252 - binary_accuracy: 0.7500
# Epoch 50/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2248 - binary_accuracy: 0.7500
# Epoch 51/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2244 - binary_accuracy: 0.7500
# Epoch 52/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2240 - binary_accuracy: 1.0000
# Epoch 53/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2236 - binary_accuracy: 1.0000
# Epoch 54/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2232 - binary_accuracy: 1.0000
# Epoch 55/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2228 - binary_accuracy: 1.0000
# Epoch 56/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2224 - binary_accuracy: 1.0000
# Epoch 57/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2219 - binary_accuracy: 1.0000
# Epoch 58/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2215 - binary_accuracy: 1.0000
# Epoch 59/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2211 - binary_accuracy: 1.0000
# Epoch 60/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2207 - binary_accuracy: 1.0000
# Epoch 61/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2203 - binary_accuracy: 1.0000
# Epoch 62/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2199 - binary_accuracy: 1.0000
# Epoch 63/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2195 - binary_accuracy: 1.0000
# Epoch 64/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2190 - binary_accuracy: 1.0000
# Epoch 65/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2186 - binary_accuracy: 1.0000
# Epoch 66/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2182 - binary_accuracy: 1.0000
# Epoch 67/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2178 - binary_accuracy: 1.0000
# Epoch 68/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2174 - binary_accuracy: 1.0000
# Epoch 69/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2169 - binary_accuracy: 1.0000
# Epoch 70/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2165 - binary_accuracy: 1.0000
# Epoch 71/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2161 - binary_accuracy: 1.0000
# Epoch 72/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2157 - binary_accuracy: 1.0000
# Epoch 73/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2152 - binary_accuracy: 1.0000
# Epoch 74/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2148 - binary_accuracy: 1.0000
# Epoch 75/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2144 - binary_accuracy: 1.0000
# Epoch 76/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2139 - binary_accuracy: 1.0000
# Epoch 77/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2135 - binary_accuracy: 1.0000
# Epoch 78/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2131 - binary_accuracy: 1.0000
# Epoch 79/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2126 - binary_accuracy: 1.0000
# Epoch 80/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2122 - binary_accuracy: 1.0000
# Epoch 81/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2118 - binary_accuracy: 1.0000
# Epoch 82/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2113 - binary_accuracy: 1.0000
# Epoch 83/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2109 - binary_accuracy: 1.0000
# Epoch 84/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2104 - binary_accuracy: 1.0000
# Epoch 85/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2100 - binary_accuracy: 1.0000
# Epoch 86/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2096 - binary_accuracy: 1.0000
# Epoch 87/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2091 - binary_accuracy: 1.0000
# Epoch 88/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2087 - binary_accuracy: 1.0000
# Epoch 89/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2082 - binary_accuracy: 1.0000
# Epoch 90/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2078 - binary_accuracy: 1.0000
# Epoch 91/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2073 - binary_accuracy: 1.0000
# Epoch 92/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2069 - binary_accuracy: 1.0000
# Epoch 93/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2064 - binary_accuracy: 1.0000
# Epoch 94/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2059 - binary_accuracy: 1.0000
# Epoch 95/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2055 - binary_accuracy: 1.0000
# Epoch 96/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2050 - binary_accuracy: 1.0000
# Epoch 97/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2046 - binary_accuracy: 1.0000
# Epoch 98/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2041 - binary_accuracy: 1.0000
# Epoch 99/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2036 - binary_accuracy: 1.0000
# Epoch 100/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2032 - binary_accuracy: 1.0000
# [[0.4798994 ]
#  [0.55492014]
#  [0.5746342 ]
#  [0.4488477 ]]

# %%
import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior() 

input_data = [[0., 0.], [0., 1.], [1., 0.], [1., 1.]]  # XOR input
output_data = [[0.], [1.], [1.], [0.]]  # XOR output

n_input = tf.placeholder(tf.float32, shape=[None, 2], name="n_input")
n_output = tf.placeholder(tf.float32, shape=[None, 1], name="n_output")

hidden_nodes = 32

b_hidden = tf.Variable(tf.random_normal([hidden_nodes]), name="hidden_bias")
W_hidden = tf.Variable(tf.random_normal([2, hidden_nodes]), name="hidden_weights")
hidden = tf.sigmoid(tf.matmul(n_input, W_hidden) + b_hidden)

W_output = tf.Variable(tf.random_normal([hidden_nodes, 1]), name="output_weights")  # output layer's weight matrix
output = tf.sigmoid(tf.matmul(hidden, W_output))  # calc output layer's activation

cross_entropy = tf.square(n_output - output)  # simpler, but also works

loss = tf.reduce_mean(cross_entropy)  # mean the cross_entropy
optimizer = tf.train.AdamOptimizer(0.01)  # take a gradient descent for optimizing with a "stepsize" of 0.1
train = optimizer.minimize(loss)  # let the optimizer train

init = tf.global_variables_initializer()

sess = tf.Session()  # create the session and therefore the graph
sess.run(init)  # initialize all variables  

for epoch in range(0, 101):
    # run the training operation
    cvalues = sess.run([train, loss, W_hidden, b_hidden, W_output],
                       feed_dict={n_input: input_data, n_output: output_data})

    if epoch % 10 == 0:
        print("")
        print("step: {:>3}".format(epoch))
        print("loss: {}".format(cvalues[1]))
# Out:
# step:   0
# loss: 0.4170713424682617
#
# step:  10
# loss: 0.305957168340683
#
# step:  20
# loss: 0.2844841182231903
#
# step:  30
# loss: 0.264631986618042
#
# step:  40
# loss: 0.2448318600654602
#
# step:  50
# loss: 0.2271743267774582
#
# step:  60
# loss: 0.20956510305404663
#
# step:  70
# loss: 0.19077812135219574
#
# step:  80
# loss: 0.17069388926029205
#
# step:  90
# loss: 0.14956419169902802
#
# step: 100
# loss: 0.1280314326286316
